# %%
using PyPlot

n = 50
srand(1)
area = pi .*(15 .* rand(n)).^2   #0 - 15 point radiuses
scatter(x = rand(n), y = rand(n), s = area, alpha = 0.5)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000189D0358>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000018F0DE48>

# %% [markdown]
# Say somethings: The below code shows us a simple equation
# $$a+b$$

# %%
#Coding here
a = 3
b = 4
println(a+b)
# Out:
# 7
